# %%
# !pip install opencv-python
# Out:
# ...
#     100% |████████████████████████████████| 41.9MB 24kB/s eta 0:00:011    56% |██████████████████              | 23.6MB 255kB/s eta 0:01:12    62% |████████████████████            | 26.2MB 700kB/s eta 0:00:23    63% |████████████████████▏           | 26.4MB 492kB/s eta 0:00:32    92% |█████████████████████████████▌  | 38.7MB 463kB/s eta 0:00:07    98% |███████████████████████████████▍| 41.2MB 901kB/s eta 0:00:01
# ...
# You are using pip version 9.0.1, however version 10.0.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
# !pip install --upgrade pip
# Out:
# ...
#     100% |████████████████████████████████| 1.3MB 146kB/s ta 0:00:01
# ...
#   Found existing installation: pip 9.0.1
#     Uninstalling pip-9.0.1:
#       Successfully uninstalled pip-9.0.1
# ...

# %%
import cv2

# %% [markdown]
# # -  step-1:loading image
# -  step-2:convert color image into gray scale
# -  step-3:thresholding image (convert gray scale image into binary image)
# -  step-4:normalizing image(0-255)-> (0-1)# no negative number
# -  dtype is float32

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import cv2# computer vision

# %%
img = cv2.imread('kajal.jpg')
img.shape
# Out:
# (515, 600, 3)

# %% [markdown]
# - row,col,depth

# %%
plt.imshow(img)

# %% [markdown]
# ### splitting and merging array

# %%
r , g ,b = cv2.split(img)
img_new = cv2.merge((b,g,r))
plt.imshow(img_new)

# %% [markdown]
# ** Converting into grey scale image

# %%
gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
print(gray.shape)
# Out:
# (515, 600)

# %%
plt.imshow(gray, cmap ='gray')
cv2.imwrite('gray.png',gray)
# Out:
# True

# %% [markdown]
# ** Thresholding

# %%
ret, thresh = cv2.threshold(gray,127,255,cv2.THRESH_BINARY)
ret, thresh1 = cv2.threshold(gray,127,255,cv2.THRESH_BINARY_INV)

# %%
#normalizing
thresh = thresh/255.0
tresh1 = thresh1/255.0

# %%
plt.imshow(thresh,cmap ='gray')

# %%
thresh
# Out:
# array([[0.00392157, 0.00392157, 0.00392157, ..., 0.00392157, 0.00392157,
#         0.00392157],
#        [0.00392157, 0.00392157, 0.00392157, ..., 0.00392157, 0.00392157,
#         0.00392157],
#        [0.00392157, 0.00392157, 0.00392157, ..., 0.00392157, 0.00392157,
#         0.00392157],
#        ...,
#        [0.00392157, 0.00392157, 0.00392157, ..., 0.00392157, 0.00392157,
#         0.00392157],
#        [0.00392157, 0.00392157, 0.00392157, ..., 0.00392157, 0.00392157,
#         0.00392157],
#        [0.00392157, 0.00392157, 0.00392157, ..., 0.00392157, 0.00392157,
#         0.00392157]])
